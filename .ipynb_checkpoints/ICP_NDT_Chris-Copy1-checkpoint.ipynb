# %% [markdown]
# # Localization
#
# *Project Memebers*
#
# Name   Marticulation Number   Contribution
#
# Jenish Thapa   k12137169
#
# Prasil Adhikari   k12049801
#
# Christoph Domberger   k51849497  ICP Localization
#
# Sebastian Ukleja   k0512011

# %% [markdown]
# ## Project Overview ##
#
# The project objective is to achieve the localization for a car driving within a simulated environment, covering a minimum distance of 170m from its starting position, while keeping the distance pose error within 1.2m. To accomplish this, we will make use of pointclouds extracted from a simulated car equipped with a lidar, which provides regular lidar scans. Additionally, there is an existing point cloud map "map.pcd" available, extracted from the CARLA simulator. We can achieve localization for the car by using point registration algorithms ICP and NDT matching between the map and the scans. We will then evaluate the disatnce pose error between the pose we get from localization algorithm and from the ground truth provided along with the dataset

# %% [markdown]
# The project objective is to achieve the localization for a car driving within a simulated environment, covering a minimum distance of 170m from its starting position, while keeping the distance pose error within 1.2m. To accomplish this, we will make use of pointclouds extracted from a simulated car equipped with a lidar, which provides regular lidar scans. Additionally, there is an existing point cloud map "map.pcd" available, extracted from the CARLA simulator. We can achieve localization for the car by using point registration algorithms ICP and NDT matching between the map and the scans. We will then evaluate the disatnce pose error between the pose we get from localization algorithm and from the ground truth provided along with the dataset

# %% [markdown]
# ## Set up ##
#
# You can set up and run this notebook by extracting the files from the zip file and later setting up the docker using the docker file in VS code. Do setup and use xlauncher to get visualization if needed

# %% [markdown]
# ## ICP Localization
#
#
# The ICP algorithm, or Iterative Closest Point algortihm, is an algorithm which is used to register two or more point clouds by refining a transformation matrix that aligns the source point cloud with the target point cloud. At each iteration, the algorithm computes the closest points between the two clouds, and then estimates a transformation matrix that aligns the source points with the target points. This process is repeated until the algorithm converges, meaning that the change in the transformation matrix between two iterations falls below a certain threshold.
#
# ### Module
#
# In the implementation the Open3D module was used with the following parameters:
#
# - voxelize = 0.2 -> sets the size of the voxels that will be used to downsample the point clouds. A smaller voxel size will result in a higher level of detail, but will also increase the computation time.
# - icp_params.relative_fitness = 1e-6 and icp_params.relative_rmse = 1e-6 -> these two parameters set the convergence criteria for the elgorithm. The relative fitness is responsible for the maximum allowed change in fitness and the relative rsme is responsible for the maximum allowed change in RSME between two consecutive iterations.
# - max_correspondence_distance = 1.6 -> sets the maximum distance between corresponding points in source and target cloud
#
# The Iteration over all frames to about 83 seconds and the distance to the map was below 1.2 meters for every frame.

# %%
import open3d as o3d
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
import copy

# %% [markdown]
# ### Load the map from the map.pcd file

# %%
map_cloud = o3d.io.read_point_cloud("dataset/map.pcd") #projects/dataset/map.pcd

# Print the number of points in the map cloud
print(f"Loaded {len(map_cloud.points)} data points from map.pcd")
# Out:
# Loaded 143949 data points from map.pcd

# %% [markdown]
# ### Iteritatively go through each frame and localize the car in the given map.

# %%
import os
import numpy as np
import time

# %%
frames_dir = "dataset/frames"
frame_files = os.listdir(frames_dir)
frames = [o3d.io.read_point_cloud(os.path.join(frames_dir, f)) for f in frame_files]

# %%
print(frames[0].get_center())
# Out:
# [-0.29560711 -0.48462959 -0.79555747]

# %%
def draw_registration_result(source, target, transformation):
    source_temp = copy.deepcopy(source)
    target_temp = copy.deepcopy(target)
    source_temp.paint_uniform_color([1, 0.706, 0])
    target_temp.paint_uniform_color([0, 0.651, 0.929])
    source_temp.transform(transformation)
    o3d.visualization.draw_plotly([source_temp, target_temp],
                                      zoom=0.4459,
                                      front=[0.9288, -0.2951, -0.2242],
                                      lookat=[1.6784, 2.0612, 1.4451],
                                      up=[-0.3402, -0.9189, -0.1996])

# %%
threshold = 0.02
trans_init = np.asarray([[0.862, 0.011, -0.507, 0.5],
                         [-0.139, 0.967, -0.215, 0.7],
                         [0.487, 0.255, 0.835, -1.4], [0.0, 0.0, 0.0, 1.0]])
draw_registration_result(map_cloud, frames[0], trans_init)

# %%
print("Initial alignment")
evaluation = o3d.pipelines.registration.evaluate_registration(
    map_cloud, frames[0], threshold, trans_init)
print(evaluation)
# Out:
# Initial alignment
# RegistrationResult with fitness=6.946905e-06, inlier_rmse=2.677878e-03, and correspondence_set size of 1
# Access transformation to get result.

# %%
print("Apply point-to-point ICP")
reg_p2p = o3d.pipelines.registration.registration_icp(
    map_cloud, frames[0], threshold, trans_init,
    o3d.pipelines.registration.TransformationEstimationPointToPoint())
print(reg_p2p)
print("Transformation is:")
print(reg_p2p.transformation)
draw_registration_result(map_cloud, frames[0], reg_p2p.transformation)
# Out:
# Apply point-to-point ICP
# RegistrationResult with fitness=6.946905e-06, inlier_rmse=0.000000e+00, and correspondence_set size of 1
# Access transformation to get result.
# Transformation is:
# [[ 0.862       0.011      -0.507       0.50254853]
#  [-0.139       0.967      -0.215       0.69950987]
#  [ 0.487       0.255       0.835      -1.39933986]
#  [ 0.          0.          0.          1.        ]]

# %%
voxel_size = 0.2
icp_params = o3d.pipelines.registration.ICPConvergenceCriteria(max_iteration=100)
icp_params.relative_fitness = 1e-6
icp_params.relative_rmse = 1e-6

# %%
# try it on 1 frame
frame_cloud = frames[0].voxel_down_sample( voxel_size = 0.2)

# %%
print(type(map_cloud))
# Out:
# <class 'open3d.cpu.pybind.geometry.PointCloud'>

# %%
start_time = time.time()

for i, frame in enumerate(frames):
    # Downsample the point cloud using a voxel grid filter
    frame_cloud_downsampled = frame.voxel_down_sample(voxel_size)

    reg_result = o3d.pipelines.registration.registration_icp(frame_cloud_downsampled, map_cloud,  max_correspondence_distance = 1.6) #did not use params yet
    
    # Evaluate the localization effectiveness
    distance = reg_result.fitness
    print(f"Frame {i}: Distance to map = {distance:.3f}m")
    failures = 0
    if distance > 1.2:
        failures = failures + 1
        print("Localization failed - maximum lateral error exceeded.")
print(f'There have been {failures} failures')

end_time = time.time()
total_time = end_time - start_time

print(f"Total execution time: {total_time:.3f} seconds")
# Out:
# Frame 0: Distance to map = 1.000m
# Frame 1: Distance to map = 1.000m
# Frame 2: Distance to map = 1.000m
# Frame 3: Distance to map = 0.812m
# Frame 4: Distance to map = 0.778m
# Frame 5: Distance to map = 0.806m
# Frame 6: Distance to map = 0.813m
# Frame 7: Distance to map = 0.808m
# Frame 8: Distance to map = 0.804m
# Frame 9: Distance to map = 0.777m
# Frame 10: Distance to map = 0.794m
# Frame 11: Distance to map = 0.804m
# Frame 12: Distance to map = 0.802m
# Frame 13: Distance to map = 0.788m
# Frame 14: Distance to map = 0.824m
# Frame 15: Distance to map = 0.816m
# Frame 16: Distance to map = 0.808m
# Frame 17: Distance to map = 0.808m
# Frame 18: Distance to map = 0.808m
# Frame 19: Distance to map = 0.808m
# Frame 20: Distance to map = 0.816m
# Frame 21: Distance to map = 0.808m
# Frame 22: Distance to map = 0.809m
# Frame 23: Distance to map = 0.812m
# Frame 24: Distance to map = 0.836m
# Frame 25: Distance to map = 0.820m
# Frame 26: Distance to map = 0.840m
# Frame 27: Distance to map = 1.000m
# Frame 28: Distance to map = 0.843m
# Frame 29: Distance to map = 0.846m
# Frame 30: Distance to map = 0.844m
# Frame 31: Distance to map = 0.856m
# Frame 32: Distance to map = 0.863m
# Frame 33: Distance to map = 0.868m
# Frame 34: Distance to map = 0.862m
# Frame 35: Distance to map = 0.849m
# Frame 36: Distance to map = 0.861m
# Frame 37: Distance to map = 0.856m
# Frame 38: Distance to map = 1.000m
# Frame 39: Distance to map = 0.857m
# Frame 40: Distance to map = 0.855m
# Frame 41: Distance to map = 0.858m
# Frame 42: Distance to map = 0.849m
# Frame 43: Distance to map = 0.848m
# Frame 44: Distance to map = 0.868m
# Frame 45: Distance to map = 0.860m
# Frame 46: Distance to map = 0.857m
# Frame 47: Distance to map = 0.851m
# Frame 48: Distance to map = 0.848m
# Frame 49: Distance to map = 1.000m
# Frame 50: Distance to map = 0.849m
# Frame 51: Distance to map = 0.849m
# Frame 52: Distance to map = 0.861m
# Frame 53: Distance to map = 0.835m
# Frame 54: Distance to map = 0.851m
# Frame 55: Distance to map = 0.851m
# Frame 56: Distance to map = 0.844m
# Frame 57: Distance to map = 0.838m
# Frame 58: Distance to map = 0.838m
# Frame 59: Distance to map = 0.821m
# Frame 60: Distance to map = 1.000m
# Frame 61: Distance to map = 0.825m
# Frame 62: Distance to map = 0.809m
# Frame 63: Distance to map = 0.810m
# Frame 64: Distance to map = 0.793m
# Frame 65: Distance to map = 0.785m
# Frame 66: Distance to map = 0.761m
# Frame 67: Distance to map = 0.750m
# Frame 68: Distance to map = 0.752m
# Frame 69: Distance to map = 0.732m
# Frame 70: Distance to map = 0.767m
# Frame 71: Distance to map = 1.000m
# Frame 72: Distance to map = 0.750m
# Frame 73: Distance to map = 0.766m
# Frame 74: Distance to map = 0.758m
# Frame 75: Distance to map = 0.757m
# Frame 76: Distance to map = 0.761m
# Frame 77: Distance to map = 0.767m
# Frame 78: Distance to map = 0.773m
# Frame 79: Distance to map = 0.756m
# Frame 80: Distance to map = 0.757m
# Frame 81: Distance to map = 0.775m
# Frame 82: Distance to map = 1.000m
# Frame 83: Distance to map = 0.782m
# Frame 84: Distance to map = 0.786m
# Frame 85: Distance to map = 0.799m
# Frame 86: Distance to map = 0.798m
# Frame 87: Distance to map = 0.790m
# Frame 88: Distance to map = 0.825m
# Frame 89: Distance to map = 0.814m
# Frame 90: Distance to map = 0.814m
# Frame 91: Distance to map = 0.815m
# Frame 92: Distance to map = 0.818m
# Frame 93: Distance to map = 1.000m
# Frame 94: Distance to map = 0.834m
# Frame 95: Distance to map = 0.840m
# Frame 96: Distance to map = 0.829m
# Frame 97: Distance to map = 0.839m
# Frame 98: Distance to map = 0.837m
# Frame 99: Distance to map = 0.838m
# Frame 100: Distance to map = 0.831m
# Frame 101: Distance to map = 0.855m
# Frame 102: Distance to map = 0.842m
# Frame 103: Distance to map = 0.846m
# Frame 104: Distance to map = 1.000m
# Frame 105: Distance to map = 0.850m
# Frame 106: Distance to map = 0.867m
# Frame 107: Distance to map = 0.840m
# Frame 108: Distance to map = 0.838m
# Frame 109: Distance to map = 0.827m
# Frame 110: Distance to map = 0.816m
# Frame 111: Distance to map = 0.831m
# Frame 112: Distance to map = 0.810m
# Frame 113: Distance to map = 0.798m
# Frame 114: Distance to map = 0.815m
# Frame 115: Distance to map = 1.000m
# Frame 116: Distance to map = 0.810m
# Frame 117: Distance to map = 0.795m
# Frame 118: Distance to map = 0.796m
# Frame 119: Distance to map = 0.776m
# Frame 120: Distance to map = 0.795m
# Frame 121: Distance to map = 0.831m
# Frame 122: Distance to map = 0.812m
# Frame 123: Distance to map = 0.827m
# Frame 124: Distance to map = 0.843m
# Frame 125: Distance to map = 0.858m
# Frame 126: Distance to map = 1.000m
# Frame 127: Distance to map = 1.000m
# Frame 128: Distance to map = 0.835m
# Frame 129: Distance to map = 0.856m
# Frame 130: Distance to map = 0.853m
# Frame 131: Distance to map = 0.850m
# Frame 132: Distance to map = 0.864m
# Frame 133: Distance to map = 0.837m
# Frame 134: Distance to map = 0.834m
# Frame 135: Distance to map = 0.838m
# Frame 136: Distance to map = 0.846m
# Frame 137: Distance to map = 0.843m
# Frame 138: Distance to map = 1.000m
# Frame 139: Distance to map = 0.849m
# Frame 140: Distance to map = 0.848m
# Frame 141: Distance to map = 0.845m
# Frame 142: Distance to map = 0.859m
# Frame 143: Distance to map = 0.856m
# Frame 144: Distance to map = 0.839m
# Frame 145: Distance to map = 0.865m
# Frame 146: Distance to map = 0.853m
# Frame 147: Distance to map = 0.861m
# Frame 148: Distance to map = 0.840m
# Frame 149: Distance to map = 1.000m
# Frame 150: Distance to map = 0.854m
# Frame 151: Distance to map = 0.839m
# Frame 152: Distance to map = 0.840m
# Frame 153: Distance to map = 0.850m
# Frame 154: Distance to map = 0.811m
# Frame 155: Distance to map = 0.805m
# Frame 156: Distance to map = 0.798m
# Frame 157: Distance to map = 0.785m
# Frame 158: Distance to map = 0.789m
# Frame 159: Distance to map = 0.788m
# Frame 160: Distance to map = 1.000m
# Frame 161: Distance to map = 0.790m
# Frame 162: Distance to map = 0.794m
# Frame 163: Distance to map = 0.800m
# Frame 164: Distance to map = 0.800m
# Frame 165: Distance to map = 0.790m
# Frame 166: Distance to map = 0.810m
# Frame 167: Distance to map = 0.805m
# Frame 168: Distance to map = 0.818m
# Frame 169: Distance to map = 0.830m
# Frame 170: Distance to map = 0.832m
# Frame 171: Distance to map = 1.000m
# Frame 172: Distance to map = 0.850m
# Frame 173: Distance to map = 0.859m
# Frame 174: Distance to map = 0.864m
# Frame 175: Distance to map = 0.864m
# Frame 176: Distance to map = 0.860m
# Frame 177: Distance to map = 0.870m
# Frame 178: Distance to map = 0.866m
# Frame 179: Distance to map = 0.875m
# Frame 180: Distance to map = 0.882m
# Frame 181: Distance to map = 0.865m
# Frame 182: Distance to map = 1.000m
# Frame 183: Distance to map = 0.877m
# Frame 184: Distance to map = 0.881m
# Frame 185: Distance to map = 0.880m
# Frame 186: Distance to map = 0.877m
# Frame 187: Distance to map = 0.867m
# Frame 188: Distance to map = 0.866m
# Frame 189: Distance to map = 0.864m
# Frame 190: Distance to map = 0.874m
# Frame 191: Distance to map = 0.847m
# Frame 192: Distance to map = 0.856m
# Frame 193: Distance to map = 1.000m
# Frame 194: Distance to map = 0.831m
# Frame 195: Distance to map = 0.815m
# Frame 196: Distance to map = 0.831m
# Frame 197: Distance to map = 0.825m
# Frame 198: Distance to map = 0.820m
# Frame 199: Distance to map = 0.812m
# Frame 200: Distance to map = 0.822m
# Frame 201: Distance to map = 0.827m
# Frame 202: Distance to map = 0.830m
# Frame 203: Distance to map = 0.833m
# Frame 204: Distance to map = 1.000m
# Frame 205: Distance to map = 0.852m
# Frame 206: Distance to map = 0.845m
# Frame 207: Distance to map = 0.864m
# Frame 208: Distance to map = 0.864m
# Frame 209: Distance to map = 0.867m
# Frame 210: Distance to map = 0.864m
# Frame 211: Distance to map = 0.857m
# Frame 212: Distance to map = 0.864m
# Frame 213: Distance to map = 0.878m
# Frame 214: Distance to map = 0.858m
# Frame 215: Distance to map = 1.000m
# Frame 216: Distance to map = 0.866m
# Frame 217: Distance to map = 0.877m
# Frame 218: Distance to map = 0.877m
# Frame 219: Distance to map = 0.874m
# Frame 220: Distance to map = 0.872m
# Frame 221: Distance to map = 0.869m
# Frame 222: Distance to map = 0.877m
# Frame 223: Distance to map = 0.872m
# Frame 224: Distance to map = 0.870m
# Frame 225: Distance to map = 0.878m
# Frame 226: Distance to map = 1.000m
# Frame 227: Distance to map = 0.875m
# Frame 228: Distance to map = 0.872m
# Frame 229: Distance to map = 0.876m
# Frame 230: Distance to map = 0.871m
# Frame 231: Distance to map = 0.870m
# Frame 232: Distance to map = 0.867m
# Frame 233: Distance to map = 0.848m
# Frame 234: Distance to map = 0.834m
# Frame 235: Distance to map = 0.828m
# Frame 236: Distance to map = 0.815m
# Frame 237: Distance to map = 1.000m
# Frame 238: Distance to map = 1.000m
# Frame 239: Distance to map = 0.805m
# Frame 240: Distance to map = 0.815m
# Frame 241: Distance to map = 0.813m
# Frame 242: Distance to map = 0.786m
# Frame 243: Distance to map = 0.800m
# Frame 244: Distance to map = 0.807m
# Frame 245: Distance to map = 0.806m
# Frame 246: Distance to map = 0.819m
# Frame 247: Distance to map = 0.830m
# Frame 248: Distance to map = 0.818m
# Frame 249: Distance to map = 1.000m
# Frame 250: Distance to map = 0.824m
# Frame 251: Distance to map = 0.812m
# Frame 252: Distance to map = 0.812m
# Frame 253: Distance to map = 0.836m
# Frame 254: Distance to map = 0.850m
# Frame 255: Distance to map = 0.849m
# Frame 256: Distance to map = 0.867m
# Frame 257: Distance to map = 0.867m
# Frame 258: Distance to map = 0.861m
# Frame 259: Distance to map = 0.865m
# Frame 260: Distance to map = 1.000m
# Frame 261: Distance to map = 0.864m
# Frame 262: Distance to map = 0.880m
# Frame 263: Distance to map = 0.870m
# Frame 264: Distance to map = 0.872m
# Frame 265: Distance to map = 0.873m
# Frame 266: Distance to map = 0.879m
# Frame 267: Distance to map = 0.886m
# Frame 268: Distance to map = 0.890m
# Frame 269: Distance to map = 0.890m
# Frame 270: Distance to map = 0.885m
# Frame 271: Distance to map = 1.000m
# Frame 272: Distance to map = 0.900m
# Frame 273: Distance to map = 0.885m
# Frame 274: Distance to map = 0.897m
# Frame 275: Distance to map = 0.888m
# Frame 276: Distance to map = 0.893m
# Frame 277: Distance to map = 0.876m
# Frame 278: Distance to map = 0.859m
# Frame 279: Distance to map = 0.859m
# Frame 280: Distance to map = 0.858m
# Frame 281: Distance to map = 0.862m
# Frame 282: Distance to map = 1.000m
# Frame 283: Distance to map = 0.854m
# Frame 284: Distance to map = 0.852m
# Frame 285: Distance to map = 0.863m
# Frame 286: Distance to map = 0.860m
# Frame 287: Distance to map = 0.850m
# Frame 288: Distance to map = 0.853m
# Frame 289: Distance to map = 0.863m
# Frame 290: Distance to map = 0.879m
# Frame 291: Distance to map = 0.882m
# Frame 292: Distance to map = 0.895m
# Frame 293: Distance to map = 1.000m
# Frame 294: Distance to map = 0.887m
# Frame 295: Distance to map = 0.901m
# Frame 296: Distance to map = 0.910m
# Frame 297: Distance to map = 0.897m
# Frame 298: Distance to map = 0.901m
# Frame 299: Distance to map = 0.902m
# Frame 300: Distance to map = 0.898m
# Frame 301: Distance to map = 0.903m
# Frame 302: Distance to map = 0.894m
# Frame 303: Distance to map = 0.894m
# Frame 304: Distance to map = 0.999m
# Frame 305: Distance to map = 0.904m
# Frame 306: Distance to map = 0.899m
# Frame 307: Distance to map = 0.895m
# Frame 308: Distance to map = 0.904m
# Frame 309: Distance to map = 0.914m
# Frame 310: Distance to map = 0.895m
# Frame 311: Distance to map = 0.905m
# Frame 312: Distance to map = 0.902m
# Frame 313: Distance to map = 0.900m
# Frame 314: Distance to map = 0.898m
# Frame 315: Distance to map = 0.997m
# Frame 316: Distance to map = 0.911m
# Frame 317: Distance to map = 0.901m
# Frame 318: Distance to map = 0.907m
# Frame 319: Distance to map = 0.913m
# Frame 320: Distance to map = 0.902m
# Frame 321: Distance to map = 0.898m
# Frame 322: Distance to map = 0.913m
# Frame 323: Distance to map = 0.909m
# Frame 324: Distance to map = 0.900m
# Frame 325: Distance to map = 0.890m
# Frame 326: Distance to map = 0.996m
# Frame 327: Distance to map = 0.883m
# Frame 328: Distance to map = 0.879m
# Frame 329: Distance to map = 0.871m
# Frame 330: Distance to map = 0.854m
# Frame 331: Distance to map = 0.845m
# Frame 332: Distance to map = 0.837m
# Frame 333: Distance to map = 0.833m
# Frame 334: Distance to map = 0.840m
# Frame 335: Distance to map = 0.833m
# Frame 336: Distance to map = 0.845m
# Frame 337: Distance to map = 0.997m
# Frame 338: Distance to map = 0.840m
# Frame 339: Distance to map = 0.831m
# Frame 340: Distance to map = 0.831m
# Frame 341: Distance to map = 0.826m
# Frame 342: Distance to map = 0.832m
# Frame 343: Distance to map = 0.825m
# Frame 344: Distance to map = 0.830m
# Frame 345: Distance to map = 0.841m
# Frame 346: Distance to map = 0.835m
# Frame 347: Distance to map = 0.845m
# Frame 348: Distance to map = 1.000m
# Frame 349: Distance to map = 0.996m
# Frame 350: Distance to map = 0.867m
# Frame 351: Distance to map = 0.869m
# Frame 352: Distance to map = 0.875m
# Frame 353: Distance to map = 0.885m
# Frame 354: Distance to map = 0.885m
# Frame 355: Distance to map = 0.886m
# Frame 356: Distance to map = 0.893m
# Frame 357: Distance to map = 0.889m
# Frame 358: Distance to map = 0.882m
# Frame 359: Distance to map = 0.889m
# Frame 360: Distance to map = 0.997m
# Frame 361: Distance to map = 0.883m
# Frame 362: Distance to map = 0.892m
# Frame 363: Distance to map = 0.897m
# Frame 364: Distance to map = 0.900m
# Frame 365: Distance to map = 0.884m
# Frame 366: Distance to map = 0.894m
# Frame 367: Distance to map = 0.888m
# Frame 368: Distance to map = 0.885m
# Frame 369: Distance to map = 0.896m
# Frame 370: Distance to map = 0.896m
# Frame 371: Distance to map = 0.998m
# Frame 372: Distance to map = 0.884m
# Frame 373: Distance to map = 0.877m
# Frame 374: Distance to map = 0.879m
# Frame 375: Distance to map = 0.864m
# Frame 376: Distance to map = 0.859m
# Frame 377: Distance to map = 0.844m
# Frame 378: Distance to map = 0.840m
# Frame 379: Distance to map = 0.818m
# Frame 380: Distance to map = 0.829m
# Frame 381: Distance to map = 0.818m
# Frame 382: Distance to map = 0.996m
# Frame 383: Distance to map = 0.812m
# Frame 384: Distance to map = 0.811m
# Frame 385: Distance to map = 0.808m
# Frame 386: Distance to map = 0.824m
# Frame 387: Distance to map = 0.830m
# Frame 388: Distance to map = 0.817m
# Frame 389: Distance to map = 0.842m
# Frame 390: Distance to map = 0.853m
# Frame 391: Distance to map = 0.838m
# Frame 392: Distance to map = 0.852m
# Frame 393: Distance to map = 0.975m
# Frame 394: Distance to map = 0.860m
# Frame 395: Distance to map = 0.867m
# Frame 396: Distance to map = 0.856m
# Frame 397: Distance to map = 0.846m
# Frame 398: Distance to map = 0.857m
# Frame 399: Distance to map = 0.875m
# Frame 400: Distance to map = 0.860m
# Frame 401: Distance to map = 0.855m
# Frame 402: Distance to map = 0.859m
# Frame 403: Distance to map = 0.856m
# Frame 404: Distance to map = 0.965m
# Frame 405: Distance to map = 0.854m
# Frame 406: Distance to map = 0.851m
# Frame 407: Distance to map = 0.848m
# Frame 408: Distance to map = 0.856m
# Frame 409: Distance to map = 0.852m
# Frame 410: Distance to map = 0.864m
# Frame 411: Distance to map = 0.877m
# Frame 412: Distance to map = 0.862m
# Frame 413: Distance to map = 0.853m
# Frame 414: Distance to map = 0.849m
# Frame 415: Distance to map = 0.914m
# Frame 416: Distance to map = 0.847m
# Frame 417: Distance to map = 0.853m
# Frame 418: Distance to map = 0.859m
# Frame 419: Distance to map = 0.849m
# Frame 420: Distance to map = 0.854m
# Frame 421: Distance to map = 0.857m
# Frame 422: Distance to map = 0.855m
# Frame 423: Distance to map = 0.863m
# Frame 424: Distance to map = 0.849m
# Frame 425: Distance to map = 0.855m
# Frame 426: Distance to map = 0.895m
# Frame 427: Distance to map = 0.849m
# Frame 428: Distance to map = 0.849m
# Frame 429: Distance to map = 0.833m
# Frame 430: Distance to map = 0.794m
# Frame 431: Distance to map = 0.794m
# Frame 432: Distance to map = 0.774m
# Frame 433: Distance to map = 0.770m
# Frame 434: Distance to map = 0.789m
# Frame 435: Distance to map = 0.769m
# Frame 436: Distance to map = 0.788m
# Frame 437: Distance to map = 0.893m
# Frame 438: Distance to map = 0.777m
# Frame 439: Distance to map = 0.768m
# Frame 440: Distance to map = 0.793m
# Frame 441: Distance to map = 0.785m
# Frame 442: Distance to map = 0.792m
# Frame 443: Distance to map = 0.808m
# Frame 444: Distance to map = 0.796m
# Frame 445: Distance to map = 0.807m
# Frame 446: Distance to map = 0.819m
# Frame 447: Distance to map = 0.830m
# Frame 448: Distance to map = 0.886m
# Frame 449: Distance to map = 0.836m
# Frame 450: Distance to map = 0.845m
# Frame 451: Distance to map = 0.854m
# Frame 452: Distance to map = 0.861m
# Frame 453: Distance to map = 0.881m
# Frame 454: Distance to map = 0.872m
# Frame 455: Distance to map = 0.876m
# Frame 456: Distance to map = 0.885m
# Frame 457: Distance to map = 0.883m
# Frame 458: Distance to map = 0.881m
# Frame 459: Distance to map = 1.000m
# Frame 460: Distance to map = 0.892m
# Frame 461: Distance to map = 0.882m
# Frame 462: Distance to map = 0.886m
# Frame 463: Distance to map = 0.880m
# Frame 464: Distance to map = 0.888m
# Frame 465: Distance to map = 0.902m
# Frame 466: Distance to map = 0.890m
# Frame 467: Distance to map = 0.903m
# Frame 468: Distance to map = 0.884m
# Frame 469: Distance to map = 0.897m
# Frame 470: Distance to map = 0.894m
# Frame 471: Distance to map = 0.880m
# Frame 472: Distance to map = 0.894m
# Frame 473: Distance to map = 0.885m
# Frame 474: Distance to map = 0.887m
# Frame 475: Distance to map = 0.865m
# Frame 476: Distance to map = 0.878m
# Frame 477: Distance to map = 0.864m
# Frame 478: Distance to map = 0.870m
# Frame 479: Distance to map = 0.846m
# Frame 480: Distance to map = 0.827m
# Frame 481: Distance to map = 0.845m
# Frame 482: Distance to map = 0.881m
# Frame 483: Distance to map = 0.829m
# Frame 484: Distance to map = 0.841m
# Frame 485: Distance to map = 0.831m
# Frame 486: Distance to map = 0.833m
# Frame 487: Distance to map = 0.826m
# Frame 488: Distance to map = 0.841m
# Frame 489: Distance to map = 0.855m
# Frame 490: Distance to map = 0.872m
# Frame 491: Distance to map = 0.883m
# Frame 492: Distance to map = 0.892m
# Frame 493: Distance to map = 0.882m
# Frame 494: Distance to map = 0.906m
# Frame 495: Distance to map = 0.911m
# Frame 496: Distance to map = 0.901m
# Frame 497: Distance to map = 0.902m
# Frame 498: Distance to map = 0.899m
# Frame 499: Distance to map = 0.901m
# Frame 500: Distance to map = 0.896m
# Frame 501: Distance to map = 0.899m
# Frame 502: Distance to map = 0.894m
# Frame 503: Distance to map = 0.899m
# Frame 504: Distance to map = 0.887m
# Frame 505: Distance to map = 0.911m
# Frame 506: Distance to map = 0.890m
# Frame 507: Distance to map = 0.909m
# Frame 508: Distance to map = 0.897m
# Frame 509: Distance to map = 0.905m
# Frame 510: Distance to map = 0.913m
# Frame 511: Distance to map = 0.910m
# Frame 512: Distance to map = 0.897m
# Frame 513: Distance to map = 0.892m
# Frame 514: Distance to map = 0.904m
# Frame 515: Distance to map = 0.875m
# Frame 516: Distance to map = 0.898m
# Frame 517: Distance to map = 0.903m
# Frame 518: Distance to map = 0.908m
# Frame 519: Distance to map = 0.907m
# Frame 520: Distance to map = 0.899m
# Frame 521: Distance to map = 0.897m
# Frame 522: Distance to map = 0.893m
# Frame 523: Distance to map = 0.900m
# Frame 524: Distance to map = 0.888m
# Frame 525: Distance to map = 0.873m
# Frame 526: Distance to map = 0.889m
# Frame 527: Distance to map = 0.842m
# Frame 528: Distance to map = 0.842m
# Frame 529: Distance to map = 0.848m
# Frame 530: Distance to map = 0.823m
# Frame 531: Distance to map = 0.828m
# Frame 532: Distance to map = 0.832m
# Frame 533: Distance to map = 0.837m
# Frame 534: Distance to map = 0.827m
# Frame 535: Distance to map = 0.824m
# Frame 536: Distance to map = 0.820m
# Frame 537: Distance to map = 0.885m
# Frame 538: Distance to map = 0.829m
# Frame 539: Distance to map = 0.813m
# Frame 540: Distance to map = 0.828m
# Frame 541: Distance to map = 0.832m
# Frame 542: Distance to map = 0.829m
# Frame 543: Distance to map = 0.836m
# Frame 544: Distance to map = 0.857m
# Frame 545: Distance to map = 0.852m
# Frame 546: Distance to map = 0.872m
# Frame 547: Distance to map = 0.869m
# Frame 548: Distance to map = 0.876m
# Frame 549: Distance to map = 0.888m
# Frame 550: Distance to map = 0.891m
# Frame 551: Distance to map = 0.898m
# Frame 552: Distance to map = 0.910m
# Frame 553: Distance to map = 0.916m
# Frame 554: Distance to map = 0.914m
# Frame 555: Distance to map = 0.913m
# Frame 556: Distance to map = 0.922m
# Frame 557: Distance to map = 0.918m
# Frame 558: Distance to map = 0.916m
# Frame 559: Distance to map = 0.873m
# Frame 560: Distance to map = 0.921m
# Frame 561: Distance to map = 0.924m
# Frame 562: Distance to map = 0.920m
# Frame 563: Distance to map = 0.913m
# Frame 564: Distance to map = 0.918m
# Frame 565: Distance to map = 0.914m
# Frame 566: Distance to map = 0.913m
# Frame 567: Distance to map = 0.913m
# Frame 568: Distance to map = 0.902m
# Frame 569: Distance to map = 0.881m
# Frame 570: Distance to map = 1.000m
# Frame 571: Distance to map = 0.862m
# Frame 572: Distance to map = 0.872m
# Frame 573: Distance to map = 0.873m
# Frame 574: Distance to map = 0.864m
# Frame 575: Distance to map = 0.864m
# Frame 576: Distance to map = 0.869m
# Frame 577: Distance to map = 0.862m
# Frame 578: Distance to map = 0.875m
# Frame 579: Distance to map = 0.876m
# Frame 580: Distance to map = 0.904m
# Frame 581: Distance to map = 0.912m
# Frame 582: Distance to map = 0.862m
# Frame 583: Distance to map = 0.911m
# Frame 584: Distance to map = 0.914m
# Frame 585: Distance to map = 0.907m
# Frame 586: Distance to map = 0.910m
# Frame 587: Distance to map = 0.912m
# Frame 588: Distance to map = 0.919m
# Frame 589: Distance to map = 0.917m
# Frame 590: Distance to map = 0.919m
# Frame 591: Distance to map = 0.907m
# Frame 592: Distance to map = 0.912m
# Frame 593: Distance to map = 0.879m
# Frame 594: Distance to map = 0.909m
# Frame 595: Distance to map = 0.916m
# Frame 596: Distance to map = 0.908m
# Frame 597: Distance to map = 0.917m
# Frame 598: Distance to map = 0.917m
# Frame 599: Distance to map = 0.915m
# Frame 600: Distance to map = 0.907m
# Frame 601: Distance to map = 0.904m
# Frame 602: Distance to map = 0.909m
# Frame 603: Distance to map = 0.905m
# Frame 604: Distance to map = 0.881m
# Frame 605: Distance to map = 0.900m
# Frame 606: Distance to map = 0.914m
# Frame 607: Distance to map = 0.901m
# Frame 608: Distance to map = 0.896m
# Frame 609: Distance to map = 0.906m
# Frame 610: Distance to map = 0.913m
# Frame 611: Distance to map = 0.884m
# Frame 612: Distance to map = 0.883m
# Frame 613: Distance to map = 0.858m
# Frame 614: Distance to map = 0.860m
# Frame 615: Distance to map = 0.869m
# Frame 616: Distance to map = 0.853m
# Frame 617: Distance to map = 0.840m
# Frame 618: Distance to map = 0.850m
# Frame 619: Distance to map = 0.821m
# Frame 620: Distance to map = 0.817m
# Frame 621: Distance to map = 0.815m
# Frame 622: Distance to map = 0.816m
# Frame 623: Distance to map = 0.835m
# Frame 624: Distance to map = 0.843m
# Frame 625: Distance to map = 0.831m
# Frame 626: Distance to map = 0.889m
# Frame 627: Distance to map = 0.846m
# Frame 628: Distance to map = 0.837m
# Frame 629: Distance to map = 0.836m
# Frame 630: Distance to map = 0.846m
# Frame 631: Distance to map = 0.848m
# Frame 632: Distance to map = 0.857m
# Frame 633: Distance to map = 0.875m
# Frame 634: Distance to map = 0.892m
# Frame 635: Distance to map = 0.886m
# Frame 636: Distance to map = 0.904m
# Frame 637: Distance to map = 0.887m
# Frame 638: Distance to map = 0.904m
# Frame 639: Distance to map = 0.908m
# Frame 640: Distance to map = 0.908m
# Frame 641: Distance to map = 0.892m
# Frame 642: Distance to map = 0.907m
# Frame 643: Distance to map = 0.915m
# Frame 644: Distance to map = 0.909m
# Frame 645: Distance to map = 0.904m
# Frame 646: Distance to map = 0.914m
# Frame 647: Distance to map = 0.914m
# Frame 648: Distance to map = 0.906m
# Frame 649: Distance to map = 0.916m
# Frame 650: Distance to map = 0.905m
# Frame 651: Distance to map = 0.915m
# Frame 652: Distance to map = 0.894m
# Frame 653: Distance to map = 0.893m
# Frame 654: Distance to map = 0.880m
# Frame 655: Distance to map = 0.858m
# Frame 656: Distance to map = 0.871m
# Frame 657: Distance to map = 0.865m
# Frame 658: Distance to map = 0.837m
# Frame 659: Distance to map = 0.901m
# Frame 660: Distance to map = 0.839m
# Frame 661: Distance to map = 0.853m
# Frame 662: Distance to map = 0.838m
# Frame 663: Distance to map = 0.836m
# Frame 664: Distance to map = 0.851m
# Frame 665: Distance to map = 0.874m
# Frame 666: Distance to map = 0.884m
# Frame 667: Distance to map = 0.884m
# Frame 668: Distance to map = 0.886m
# Frame 669: Distance to map = 0.902m
# Frame 670: Distance to map = 0.897m
# Frame 671: Distance to map = 0.898m
# Frame 672: Distance to map = 0.896m
# Frame 673: Distance to map = 0.906m
# Frame 674: Distance to map = 0.898m
# Frame 675: Distance to map = 0.904m
# Frame 676: Distance to map = 0.891m
# Frame 677: Distance to map = 0.913m
# Frame 678: Distance to map = 0.896m
# Frame 679: Distance to map = 0.900m
# Frame 680: Distance to map = 0.898m
# Frame 681: Distance to map = 1.000m
# Frame 682: Distance to map = 0.897m
# Frame 683: Distance to map = 0.898m
# Frame 684: Distance to map = 0.897m
# Frame 685: Distance to map = 0.911m
# Frame 686: Distance to map = 0.912m
# Frame 687: Distance to map = 0.907m
# Frame 688: Distance to map = 0.894m
# Frame 689: Distance to map = 0.896m
# Frame 690: Distance to map = 0.905m
# Frame 691: Distance to map = 0.891m
# Frame 692: Distance to map = 0.901m
# Frame 693: Distance to map = 0.903m
# Frame 694: Distance to map = 0.900m
# Frame 695: Distance to map = 0.908m
# Frame 696: Distance to map = 0.899m
# Frame 697: Distance to map = 0.892m
# Frame 698: Distance to map = 0.870m
# Frame 699: Distance to map = 0.870m
# Frame 700: Distance to map = 0.844m
# Frame 701: Distance to map = 0.852m
# Frame 702: Distance to map = 0.826m
# Frame 703: Distance to map = 0.843m
# Frame 704: Distance to map = 0.913m
# Frame 705: Distance to map = 0.847m
# Frame 706: Distance to map = 0.832m
# Frame 707: Distance to map = 0.826m
# Frame 708: Distance to map = 0.845m
# Frame 709: Distance to map = 0.848m
# Frame 710: Distance to map = 0.839m
# Frame 711: Distance to map = 0.854m
# Frame 712: Distance to map = 0.842m
# Frame 713: Distance to map = 0.866m
# Frame 714: Distance to map = 0.860m
# Frame 715: Distance to map = 0.913m
# Frame 716: Distance to map = 0.863m
# Frame 717: Distance to map = 0.873m
# Frame 718: Distance to map = 0.889m
# Frame 719: Distance to map = 0.905m
# Frame 720: Distance to map = 0.899m
# Frame 721: Distance to map = 0.907m
# Frame 722: Distance to map = 0.911m
# Frame 723: Distance to map = 0.914m
# Frame 724: Distance to map = 0.916m
# Frame 725: Distance to map = 0.920m
# Frame 726: Distance to map = 0.907m
# Frame 727: Distance to map = 0.927m
# Frame 728: Distance to map = 0.928m
# Frame 729: Distance to map = 0.929m
# Frame 730: Distance to map = 0.929m
# Frame 731: Distance to map = 0.926m
# Frame 732: Distance to map = 0.937m
# Frame 733: Distance to map = 0.940m
# Frame 734: Distance to map = 0.936m
# Frame 735: Distance to map = 0.943m
# Frame 736: Distance to map = 0.936m
# Frame 737: Distance to map = 0.914m
# Frame 738: Distance to map = 0.932m
# Frame 739: Distance to map = 0.932m
# Frame 740: Distance to map = 0.929m
# Frame 741: Distance to map = 0.923m
# Frame 742: Distance to map = 0.914m
# Frame 743: Distance to map = 0.909m
# Frame 744: Distance to map = 0.914m
# Frame 745: Distance to map = 0.907m
# Frame 746: Distance to map = 0.910m
# Frame 747: Distance to map = 0.902m
# Frame 748: Distance to map = 0.911m
# Frame 749: Distance to map = 0.902m
# Frame 750: Distance to map = 0.901m
# Frame 751: Distance to map = 0.899m
# Frame 752: Distance to map = 0.915m
# Frame 753: Distance to map = 0.931m
# Frame 754: Distance to map = 0.948m
# Frame 755: Distance to map = 0.954m
# Frame 756: Distance to map = 0.962m
# Frame 757: Distance to map = 0.960m
# Frame 758: Distance to map = 0.963m
# Frame 759: Distance to map = 0.911m
# Frame 760: Distance to map = 0.964m
# Frame 761: Distance to map = 0.965m
# Frame 762: Distance to map = 0.958m
# Frame 763: Distance to map = 0.966m
# Frame 764: Distance to map = 0.958m
# Frame 765: Distance to map = 0.958m
# Frame 766: Distance to map = 0.963m
# Frame 767: Distance to map = 0.953m
# Frame 768: Distance to map = 0.961m
# Frame 769: Distance to map = 0.958m
# Frame 770: Distance to map = 0.922m
# Frame 771: Distance to map = 0.958m
# Frame 772: Distance to map = 0.954m
# Frame 773: Distance to map = 0.954m
# Frame 774: Distance to map = 0.948m
# Frame 775: Distance to map = 0.956m
# Frame 776: Distance to map = 0.956m
# Frame 777: Distance to map = 0.951m
# Frame 778: Distance to map = 0.955m
# Frame 779: Distance to map = 0.947m
# Frame 780: Distance to map = 0.944m
# Frame 781: Distance to map = 0.921m
# Frame 782: Distance to map = 0.937m
# Frame 783: Distance to map = 0.935m
# Frame 784: Distance to map = 0.935m
# Frame 785: Distance to map = 0.938m
# Frame 786: Distance to map = 0.935m
# Frame 787: Distance to map = 0.930m
# Frame 788: Distance to map = 0.920m
# Frame 789: Distance to map = 0.916m
# Frame 790: Distance to map = 0.917m
# Frame 791: Distance to map = 0.905m
# Frame 792: Distance to map = 1.000m
# Frame 793: Distance to map = 0.923m
# Frame 794: Distance to map = 0.893m
# Frame 795: Distance to map = 0.872m
# Frame 796: Distance to map = 0.844m
# Frame 797: Distance to map = 0.840m
# Frame 798: Distance to map = 0.824m
# Frame 799: Distance to map = 0.837m
# Frame 800: Distance to map = 0.837m
# Frame 801: Distance to map = 0.807m
# Frame 802: Distance to map = 0.729m
# Frame 803: Distance to map = 0.688m
# Frame 804: Distance to map = 0.920m
# Frame 805: Distance to map = 0.714m
# Frame 806: Distance to map = 0.714m
# Frame 807: Distance to map = 0.816m
# Frame 808: Distance to map = 0.743m
# Frame 809: Distance to map = 0.735m
# Frame 810: Distance to map = 0.802m
# Frame 811: Distance to map = 0.811m
# Frame 812: Distance to map = 0.822m
# Frame 813: Distance to map = 0.814m
# Frame 814: Distance to map = 0.810m
# Frame 815: Distance to map = 0.923m
# Frame 816: Distance to map = 0.815m
# Frame 817: Distance to map = 0.808m
# Frame 818: Distance to map = 0.798m
# Frame 819: Distance to map = 0.807m
# Frame 820: Distance to map = 0.813m
# Frame 821: Distance to map = 0.811m
# Frame 822: Distance to map = 0.806m
# Frame 823: Distance to map = 0.806m
# Frame 824: Distance to map = 0.813m
# Frame 825: Distance to map = 0.811m
# Frame 826: Distance to map = 0.923m
# Frame 827: Distance to map = 0.819m
# Frame 828: Distance to map = 0.805m
# Frame 829: Distance to map = 0.806m
# Frame 830: Distance to map = 0.814m
# Frame 831: Distance to map = 0.825m
# Frame 832: Distance to map = 0.814m
# Frame 833: Distance to map = 0.821m
# Frame 834: Distance to map = 0.825m
# Frame 835: Distance to map = 0.834m
# Frame 836: Distance to map = 0.818m
# Frame 837: Distance to map = 0.919m
# Frame 838: Distance to map = 0.814m
# Frame 839: Distance to map = 0.831m
# Frame 840: Distance to map = 0.812m
# Frame 841: Distance to map = 0.818m
# Frame 842: Distance to map = 0.818m
# Frame 843: Distance to map = 0.802m
# Frame 844: Distance to map = 0.802m
# Frame 845: Distance to map = 0.774m
# Frame 846: Distance to map = 0.759m
# Frame 847: Distance to map = 0.739m
# Frame 848: Distance to map = 0.912m
# Frame 849: Distance to map = 0.760m
# Frame 850: Distance to map = 0.785m
# Frame 851: Distance to map = 0.731m
# Frame 852: Distance to map = 0.797m
# Frame 853: Distance to map = 0.764m
# Frame 854: Distance to map = 0.731m
# Frame 855: Distance to map = 0.792m
# Frame 856: Distance to map = 0.757m
# Frame 857: Distance to map = 0.800m
# Frame 858: Distance to map = 0.822m
# Frame 859: Distance to map = 0.922m
# Frame 860: Distance to map = 0.812m
# Frame 861: Distance to map = 0.793m
# Frame 862: Distance to map = 0.808m
# Frame 863: Distance to map = 0.820m
# Frame 864: Distance to map = 0.833m
# Frame 865: Distance to map = 0.833m
# Frame 866: Distance to map = 0.814m
# Frame 867: Distance to map = 0.823m
# Frame 868: Distance to map = 0.822m
# Frame 869: Distance to map = 0.838m
# Frame 870: Distance to map = 0.915m
# Frame 871: Distance to map = 0.827m
# Frame 872: Distance to map = 0.825m
# Frame 873: Distance to map = 0.825m
# Frame 874: Distance to map = 0.821m
# Frame 875: Distance to map = 0.829m
# Frame 876: Distance to map = 0.824m
# Frame 877: Distance to map = 0.816m
# Frame 878: Distance to map = 0.821m
# Frame 879: Distance to map = 0.826m
# Frame 880: Distance to map = 0.828m
# Frame 881: Distance to map = 0.915m
# Frame 882: Distance to map = 0.837m
# Frame 883: Distance to map = 0.829m
# Frame 884: Distance to map = 0.829m
# Frame 885: Distance to map = 0.822m
# Frame 886: Distance to map = 0.822m
# Frame 887: Distance to map = 0.825m
# Frame 888: Distance to map = 0.822m
# Frame 889: Distance to map = 0.832m
# Frame 890: Distance to map = 0.824m
# Frame 891: Distance to map = 0.833m
# Frame 892: Distance to map = 0.900m
# Frame 893: Distance to map = 0.838m
# Frame 894: Distance to map = 0.824m
# Frame 895: Distance to map = 0.825m
# Frame 896: Distance to map = 0.829m
# Frame 897: Distance to map = 0.833m
# Frame 898: Distance to map = 0.834m
# Frame 899: Distance to map = 0.806m
# Frame 900: Distance to map = 0.830m
# Frame 901: Distance to map = 0.790m
# Frame 902: Distance to map = 0.764m
# Frame 903: Distance to map = 1.000m
# Frame 904: Distance to map = 0.911m
# Frame 905: Distance to map = 0.767m
# Frame 906: Distance to map = 0.761m
# Frame 907: Distance to map = 0.792m
# Frame 908: Distance to map = 0.783m
# Frame 909: Distance to map = 0.779m
# Frame 910: Distance to map = 0.780m
# Frame 911: Distance to map = 0.792m
# Frame 912: Distance to map = 0.768m
# Frame 913: Distance to map = 0.781m
# Frame 914: Distance to map = 0.776m
# Frame 915: Distance to map = 0.899m
# Frame 916: Distance to map = 0.772m
# Frame 917: Distance to map = 0.783m
# Frame 918: Distance to map = 0.769m
# Frame 919: Distance to map = 0.786m
# Frame 920: Distance to map = 0.765m
# Frame 921: Distance to map = 0.781m
# Frame 922: Distance to map = 0.781m
# Frame 923: Distance to map = 0.775m
# Frame 924: Distance to map = 0.779m
# Frame 925: Distance to map = 0.771m
# Frame 926: Distance to map = 0.897m
# Frame 927: Distance to map = 0.776m
# Frame 928: Distance to map = 0.791m
# Frame 929: Distance to map = 0.779m
# Frame 930: Distance to map = 0.781m
# Frame 931: Distance to map = 0.795m
# Frame 932: Distance to map = 0.800m
# Frame 933: Distance to map = 0.806m
# Frame 934: Distance to map = 0.784m
# Frame 935: Distance to map = 0.806m
# Frame 936: Distance to map = 0.791m
# Frame 937: Distance to map = 0.877m
# Frame 938: Distance to map = 0.796m
# Frame 939: Distance to map = 0.804m
# Frame 940: Distance to map = 0.794m
# Frame 941: Distance to map = 0.794m
# Frame 942: Distance to map = 0.808m
# Frame 943: Distance to map = 0.788m
# Frame 944: Distance to map = 0.805m
# Frame 945: Distance to map = 0.793m
# Frame 946: Distance to map = 0.782m
# Frame 947: Distance to map = 0.808m
# Frame 948: Distance to map = 0.864m
# Frame 949: Distance to map = 0.786m
# Frame 950: Distance to map = 0.783m
# Frame 951: Distance to map = 0.804m
# Frame 952: Distance to map = 0.809m
# Frame 953: Distance to map = 0.794m
# Frame 954: Distance to map = 0.804m
# Frame 955: Distance to map = 0.785m
# Frame 956: Distance to map = 0.800m
# Frame 957: Distance to map = 0.800m
# Frame 958: Distance to map = 0.797m
# Frame 959: Distance to map = 0.857m
# Frame 960: Distance to map = 0.809m
# Frame 961: Distance to map = 0.812m
# Frame 962: Distance to map = 0.788m
# Frame 963: Distance to map = 0.809m
# Frame 964: Distance to map = 0.809m
# Frame 965: Distance to map = 0.794m
# Frame 966: Distance to map = 0.795m
# Frame 967: Distance to map = 0.774m
# Frame 968: Distance to map = 0.807m
# Frame 969: Distance to map = 0.795m
# Frame 970: Distance to map = 0.834m
# Frame 971: Distance to map = 0.796m
# Frame 972: Distance to map = 0.782m
# Frame 973: Distance to map = 0.786m
# Frame 974: Distance to map = 0.800m
# Frame 975: Distance to map = 0.792m
# Frame 976: Distance to map = 0.796m
# Frame 977: Distance to map = 0.812m
# Frame 978: Distance to map = 0.794m
# Frame 979: Distance to map = 0.783m
# Frame 980: Distance to map = 0.800m
# Frame 981: Distance to map = 0.826m
# Frame 982: Distance to map = 0.788m
# Frame 983: Distance to map = 0.791m
# Frame 984: Distance to map = 0.788m
# Frame 985: Distance to map = 0.801m
# Frame 986: Distance to map = 0.810m
# Frame 987: Distance to map = 0.797m
# Frame 988: Distance to map = 0.798m
# Frame 989: Distance to map = 0.796m
# Frame 990: Distance to map = 0.764m
# Frame 991: Distance to map = 0.799m
# Frame 992: Distance to map = 0.826m
# Frame 993: Distance to map = 0.817m
# Frame 994: Distance to map = 0.806m
# Frame 995: Distance to map = 0.802m
# Frame 996: Distance to map = 0.799m
# Frame 997: Distance to map = 0.789m
# Frame 998: Distance to map = 0.800m
# Frame 999: Distance to map = 0.790m
# Frame 1000: Distance to map = 0.801m
# Frame 1001: Distance to map = 0.800m
# Frame 1002: Distance to map = 0.787m
# Frame 1003: Distance to map = 0.826m
# Frame 1004: Distance to map = 0.794m
# Frame 1005: Distance to map = 0.798m
# Frame 1006: Distance to map = 0.809m
# Frame 1007: Distance to map = 0.812m
# Frame 1008: Distance to map = 0.812m
# Frame 1009: Distance to map = 0.795m
# Frame 1010: Distance to map = 0.807m
# Frame 1011: Distance to map = 0.809m
# Frame 1012: Distance to map = 0.782m
# Frame 1013: Distance to map = 0.803m
# There have been 0 failures
# Total execution time: 82.763 seconds

# %% [markdown]
# ### Use performance measures to evaluate the localization effectiviness.
#
# Remember that to pass this task, the maximum lateral error cannot be bigger than 1.2 meters.

# %% [markdown]
# ## NDT Localization
#
# In this implementation the poincloud library (https://pointclouds.org/) was used, with python bindings from (https://github.com/hummat/registration).
# The bindings were slightly adopted for our use case and the pcl110 registration library was used.
#
#
# ### Module
# The module uses mostly default parameter except the following:
# - epsilon: was chosen for 0.001 to be in line with the assignment
# - downsample: was chosen as 0.5 to speed up the transform calculation
# - voxelize: is set to 0.2 to help again with computation time
#
# The distance threshold and inlier threshold had no measerable effect on the performance when tuning it within reasonable ranges.

# %%
from typing import Tuple, List

import numpy as np
import open3d as o3d
import os
import copy
import numpy as np
import matplotlib.pyplot as plt
import exercises.tools.utils as utils
from matplotlib import animation, rc
import matplotlib.pyplot as plt
from scipy.stats import multivariate_normal
from IPython.display import display, Math, Latex, Markdown, HTML

# %matplotlib inline

# %%
#lib wrapper for cpp registration libary slightly altered from: https://github.com/hummat/registration
#using registration library pcl110
import os
import ctypes
import csv

import numpy as np


def load_library(path: str = os.getcwd(), name: str = "libregistration_pcl110") -> None:
    global REGLIB
    try:
        REGLIB = np.ctypeslib.load_library(libname=name, loader_path=path)
        print(REGLIB)
    except OSError:
        print("Compiled C++ library was not found in the current directory. Please use `load_library` to load it from "
              "a custom directory, then ignore this message.")


load_library()


def load_data(path: str, delimiter: str = ' ') -> np.ndarray:
    """Loads point cloud data of type `CSV`, `PLY` and `PCD`.

    The file should contain one point per line where each number is separated by the `delimiter` character.
    Any none numeric lines will be skipped.

    Args:
        path (str): The path to the file.
        delimiter (char): Separation of numbers in each line of the file.

    Returns:
        A ndarray of shape NxD where `N` are the number of points in the point cloud and `D` their dimension.
    """
    data = list()
    with open(path, newline='\n') as file:
        reader = csv.reader(file, delimiter=delimiter, quoting=csv.QUOTE_NONNUMERIC)
        lines = 0
        skips = 0
        while True:
            try:
                row = next(reader)
                row = [x for x in row if not isinstance(x, str)]
                if len(row) in [3, 6, 9]:
                    data.append(row[:3])
                else:
                    skips += 1
            except ValueError:
                skips += 1
                pass
            except StopIteration:
                print(f"Found {lines} lines. Skipped {skips}. Loaded {lines - skips} points.")
                break
            lines += 1
    return np.array(data)


def set_argtypes(algorithm, source, target):
    """Tells the underlying C++ code which data types and dimensions to expect.

    Args:
        algorithm (str): The registration algorithm to use. One of `icp` or `ndt`.
        source (ndarray): The source point cloud.
        target (ndarray): The target point cloud.
    """
    REGLIB.icp.restype = ctypes.c_double
    REGLIB.ndt.restype = ctypes.c_double
    argtypes = [np.ctypeslib.ndpointer(dtype=np.float64, ndim=source.ndim, shape=source.shape,
                                       flags='C_CONTIGUOUS'), ctypes.c_size_t,
                np.ctypeslib.ndpointer(dtype=np.float64, ndim=target.ndim, shape=target.shape,
                                       flags='C_CONTIGUOUS'), ctypes.c_size_t,
                np.ctypeslib.ndpointer(dtype=np.float64, ndim=2, shape=(4, 4), flags='C_CONTIGUOUS'),
                ctypes.c_int, ctypes.c_double, ctypes.c_double, ctypes.c_double, ctypes.c_double, ctypes.c_bool]
    if algorithm == 'icp':
        REGLIB.icp.argtypes = argtypes
    elif algorithm == 'ndt':
        argtypes.extend([ctypes.c_float, ctypes.c_double, ctypes.c_float])
        REGLIB.ndt.argtypes = argtypes


def icp(source,
        target,
        nr_iterations=25,
        distance_threshold=1.0,
        epsilon=0.01,
        inlier_threshold=0.05,
        downsample=0,
        visualize=False):
    """The `Iterative Closest Point` (ICP) algorithm.

    Args:
        source (ndarray): The point cloud that we want to align to the target.
        target (ndarray): The point cloud that the source is aligned to.
        nr_iterations (int): The maximum number of iterations the internal optimization should run for.
        distance_threshold (float): The maximum distance threshold between two correspondent points in
                                    source -> target. If the distance is larger than this threshold, the points will
                                    be ignored in the alignment process.
        epsilon (float): The transformation epsilon (maximum allowable difference between two consecutive
                 transformations) in order for an optimization to be considered as having converged to the final
                 solution.
        inlier_threshold (float): The inlier distance threshold for the internal RANSAC outlier rejection loop.
                          The method considers a point to be an inlier, if the distance between the target data
                          index and the transformed source index is smaller than the given inlier distance
                          threshold.
        downsample (float): Assembles a local 3D grid over a given PointCloud and downsamples + filters the data.
        visualize (bool): Can be used to visualize and control the progress of the algorithm.

    Returns:
        A ndarray with the final transformation matrix between source and target.
    """

    transformation = np.identity(4)
    set_argtypes('icp', source, target)
    score = REGLIB.icp(source, len(source), target, len(target), transformation,
                       nr_iterations, distance_threshold, epsilon, inlier_threshold, downsample, visualize)
    print(f"ICP converged. Fitness score: {score:.2f}") if score > 0 else print("ICP did not converge!")
    return transformation


def ndt(source,
        target,
        nr_iterations=25,
        distance_threshold=1.0,
        epsilon=0.01,
        inlier_threshold=0.05,
        downsample=0,
        visualize=False,
        resolution=1.0,
        step_size=0.1,
        voxelize=0):
    """The `Normal Distributions Transform` (NDT) algorithm.

    Args:
        source (ndarray): The point cloud that we want to align to the target.
        target (ndarray): The point cloud that the source is aligned to.
        nr_iterations (int): The maximum number of iterations the internal optimization should run for.
        distance_threshold (float): The maximum distance threshold between two correspondent points in
                                    source -> target. If the distance is larger than this threshold, the points will
                                    be ignored in the alignment process.
        epsilon (float): The transformation epsilon (maximum allowable difference between two consecutive
                 transformations) in order for an optimization to be considered as having converged to the final
                 solution.
        inlier_threshold (float): The inlier distance threshold for the internal RANSAC outlier rejection loop.
                          The method considers a point to be an inlier, if the distance between the target data
                          index and the transformed source index is smaller than the given inlier distance
                          threshold.
        downsample (float): Assembles a local 3D grid over a given PointCloud and downsamples + filters the data.
        visualize (bool): Can be used to visualize and control the progress of the algorithm.
        resolution (float): The resolution of the voxel grid. Try increasing this in case of core dumps.
        step_size (float): The Newton line search maximum step length.
        voxelize (bool): If set to `True`, the source cloud is converted into a voxel model before alignment.

    Returns:
        A ndarray with the final transformation matrix between source and target.
    """

    transformation = np.identity(4)
    set_argtypes('ndt', source, target)
    score = REGLIB.ndt(source, len(source), target, len(target), transformation,
                  nr_iterations, distance_threshold, epsilon, inlier_threshold, downsample, visualize,
                  resolution, step_size, voxelize)
    #print(f"NDT converged. Fitness score: {score:.2f}") if score > 0 else print("NDT did not converge!")
    return transformation, score

# %% [markdown]
# ## Analysis
#
# ### RMSE
#
# ### Runtime
# Without any downsampling the *ndt* needs around 15 seconds for the calculation of one transform from our data set. With the chosen downsampling
# and voxelization parameter, the calculation takes only roughly one second. While trying the algorithm on not downsampled data samples,
# no performance difference could be observed.

# %%
import os
from tqdm import tqdm
import time


load_library("app/libregistration_pcl18.so")
target_points = load_data("app/dataset/map.pcd")
transformation_list = []
score_lst = []
samples = 10

#loops over all frames and returns the ndt transformation matrices and the core calculated by the cpp library
for sample in tqdm(range(samples)):

    frame_path = os.path.join("app/dataset/frames/", frame_files[sample])
    source_points = load_data(frame_path)
    if sample == 9:
        trans, score = ndt(source=source_points, target=target_points, nr_iterations=1, epsilon=0.001,
                            inlier_threshold=0.05, distance_threshold=0.5, downsample=0.5, visualize=True,
                            voxelize=0.2)
    else:
        trans, score = ndt(source=source_points, target=target_points, nr_iterations=1, epsilon=0.001,
                            inlier_threshold=0.05, distance_threshold=0.5, downsample=0.5, visualize=False,
                            voxelize=0.2)

    transformation_list.append(trans)
    score_lst.append(score)

# %%
print(f'Mean Score: {sum(score_lst)/len(score_lst)}')
print(transformation_list[9])
